# %%
import matplotlib.pyplot as plt

# 四类二维数据
data1_x = [1, 2, 3, 4, 5, 6, 7, 8]
data1_y = [0.9953, 0.9458, 0.7759, 0.7514, 0.8152, 0.7560, 0.7261, 0.6668]

data2_x = [1, 2, 3, 4, 5, 6, 7, 8]
data2_y = [0.9953, 0.9573, 0.8345, 0.8480, 0.8590, 0.7962, 0.7904, 0.7492]

data3_x = [1, 2, 3, 4, 5, 6, 7, 8]
data3_y = [0.9953, 0.9323, 0.8282, 0.8503, 0.8648, 0.8189, 0.7906, 0.7589]

data0_x = [1, 2, 3, 4, 5, 6, 7, 8]
data0_y = [0.9953, 0.1006, 0.1249, 0.0876, 0.0785, 0.0312, 0.0474, 0.0628]


# 创建折线图
plt.plot(data0_x, data0_y, label='Sequence Learning', marker='d', linestyle=':')
plt.plot(data1_x, data1_y, label='No Distilling', marker='o', linestyle='-')
plt.plot(data2_x, data2_y, label='Grassmann', marker='s', linestyle='--')
plt.plot(data3_x, data3_y, label='Wasserstein', marker='^', linestyle='-.')


# 添加标题和标签
plt.title('MEM = 32')
plt.xlabel('Task')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()

# %%
data1_x = [1, 2, 3, 4, 5, 6, 7, 8]
data1_y = [0.9953, 0.9432, 0.8902, 0.8556, 0.8383, 0.7808, 0.8270, 0.7787]

data2_x = [1, 2, 3, 4, 5, 6, 7, 8]
data2_y = [0.9953, 0.9578, 0.8767, 0.8760, 0.8783, 0.8657, 0.8655, 0.8295]

data3_x = [1, 2, 3, 4, 5, 6, 7, 8]
data3_y = [0.9953, 0.9575, 0.9064, 0.8646, 0.8394, 0.8424, 0.8438, 0.8024]

data0_x = [1, 2, 3, 4, 5, 6, 7, 8]
data0_y = [0.9953, 0.1006, 0.1249, 0.0876, 0.0785, 0.0312, 0.0474, 0.0628]


# 创建折线图
plt.plot(data0_x, data0_y, label='Sequence Learning', marker='d', linestyle=':')
plt.plot(data1_x, data1_y, label='No Distilling', marker='o', linestyle='-')
plt.plot(data2_x, data2_y, label='Grassmann', marker='s', linestyle='--')
plt.plot(data3_x, data3_y, label='Wasserstein', marker='^', linestyle='-.')

# 添加标题和标签
plt.title('MEM = 64')
plt.xlabel('Task')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()

# %%
data1_x = [1, 2, 3, 4, 5, 6, 7, 8]
data1_y = [0.9953, 0.9649, 0.9454, 0.8792, 0.8819, 0.8274, 0.8726, 0.8683]

data2_x = [1, 2, 3, 4, 5, 6, 7, 8]
data2_y = [0.9953, 0.9676, 0.9359, 0.8826, 0.8857, 0.8485, 0.8677, 0.8550]

data3_x = [1, 2, 3, 4, 5, 6, 7, 8]
data3_y = [0.9953, 0.9756, 0.9385, 0.8845, 0.8667, 0.8283, 0.8624, 0.8778]

data0_x = [1, 2, 3, 4, 5, 6, 7, 8]
data0_y = [0.9953, 0.1006, 0.1249, 0.0876, 0.0785, 0.0312, 0.0474, 0.0628]


# 创建折线图
plt.plot(data0_x, data0_y, label='Sequence Learning', marker='d', linestyle=':')
plt.plot(data1_x, data1_y, label='No Distilling', marker='o', linestyle='-')
plt.plot(data2_x, data2_y, label='Grassmann', marker='s', linestyle='--')
plt.plot(data3_x, data3_y, label='Wasserstein', marker='^', linestyle='-.')

# 添加标题和标签
plt.title('MEM = 128')
plt.xlabel('Task')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()

# %%
data1_x = [1, 2, 3, 4, 5, 6, 7, 8]
data1_y = [0.9953, 0.9578, 0.9438, 0.9171, 0.9107, 0.8807, 0.8653, 0.8580]

data2_x = [1, 2, 3, 4, 5, 6, 7, 8]
data2_y = [0.9953, 0.9692, 0.9438, 0.8954, 0.9003, 0.8774, 0.8679, 0.8732]

data3_x = [1, 2, 3, 4, 5, 6, 7, 8]
data3_y = [0.9953, 0.9697, 0.9492, 0.9005, 0.9065, 0.8863, 0.8604, 0.8633]

data0_x = [1, 2, 3, 4, 5, 6, 7, 8]
data0_y = [0.9953, 0.1006, 0.1249, 0.0876, 0.0785, 0.0312, 0.0474, 0.0628]


# 创建折线图
plt.plot(data0_x, data0_y, label='Sequence Learning', marker='d', linestyle=':')
plt.plot(data1_x, data1_y, label='No Distilling', marker='o', linestyle='-')
plt.plot(data2_x, data2_y, label='Grassmann', marker='s', linestyle='--')
plt.plot(data3_x, data3_y, label='Wasserstein', marker='^', linestyle='-.')

# 添加标题和标签
plt.title('MEM = 256')
plt.xlabel('Task')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

# 四类二维数据
data1_x = [1, 2, 3, 4, 5, 6, 7, 8]
data1_y = [0.9953, 0.9058, 0.8159, 0.7714, 0.7952, 0.7760, 0.7561, 0.7168]

data2_x = [1, 2, 3, 4, 5, 6, 7, 8]
data2_y = [0.9953, 0.9573, 0.8345, 0.8280, 0.8090, 0.7862, 0.7804, 0.7792]

data3_x = [1, 2, 3, 4, 5, 6, 7, 8]
data3_y = [0.9953, 0.9323, 0.8282, 0.8380, 0.8490, 0.7762, 0.7704, 0.7892]

data0_x = [1, 2, 3, 4, 5, 6, 7, 8]
data0_y = [0.9953, 0.1006, 0.1249, 0.0876, 0.0785, 0.0312, 0.0474, 0.0628]


# 创建折线图
plt.plot(data0_x, data0_y, label='Sequence Learning', marker='d', linestyle=':')
plt.plot(data1_x, data1_y, label='No Distilling', marker='o', linestyle='-')
plt.plot(data2_x, data2_y, label='Grassmann', marker='s', linestyle='--')
plt.plot(data3_x, data3_y, label='Wasserstein', marker='^', linestyle='-.')


# 添加标题和标签
plt.title('MEM = 128')
plt.xlabel('Task')
plt.ylabel('Accuracy')

# 添加图例
plt.legend()

# 显示图表
plt.show()
